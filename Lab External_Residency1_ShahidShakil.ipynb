# %% [markdown]
# ## About the dataset
#
# This is perhaps the best known database to be found in the pattern recognition literature. The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.  One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
#
# Attribute Information:
#    1. sepal length in cm
#    2. sepal width in cm
#    3. petal length in cm
#    4. petal width in cm
#    5. class:
#       -- Iris Setosa
#       -- Iris Versicolour
#       -- Iris Virginica

# %% [markdown]
# ### Read the dataset and store it in the dataframe named Iris

# %%
import pandas as pd
iris=pd.read_csv("/home/shahid/anaconda3/Iris.csv")
print(type(iris))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ### Find out the datatypes of each and every column

# %%
iris.dtypes
# Out:
# Sepal Length (in cm)    float64
# Sepal Width in (cm)     float64
# Petal length (in cm)    float64
# Petal width (in cm)     float64
# Class                    object
# dtype: object

# %% [markdown]
# ### Print top 10 & bottom 10 samples from the dataframe

# %%
print("The top 10 values of Data Frame  are following \n\n"+ str(iris.head()))
print("-----------------------------------------------------")
print("The bottom 10 values of Data Frame are follwing  \n\n"+ str(iris.tail()))
# Out:
# The top 10 values of Data Frame  are following
#
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.2  Iris-setosa
# -----------------------------------------------------
# The bottom 10 values of Data Frame are follwing
#
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 145                  2.3  Iris-virginica
# 146                  1.9  Iris-virginica
# 147                  2.0  Iris-virginica
# 148                  2.3  Iris-virginica
# 149                  1.8  Iris-virginica

# %% [markdown]
# ### Find the shape of the dataset

# %%
iris.shape
# Out:
# (150, 5)

# %% [markdown]
# ### Set the index of the dataframe to be the first column

# %%
iris.set_index("Sepal Length (in cm)")
# Out:
#                       Sepal Width in (cm)  Petal length (in cm)  \
# Sepal Length (in cm)
# 5.1                                   3.5                   1.4
# 4.9                                   3.0                   1.4
# 4.7                                   3.2                   1.3
# 4.6                                   3.1                   1.5
# 5.0                                   3.6                   1.4
# 5.4                                   3.9                   1.7
# 4.6                                   3.4                   1.4
# 5.0                                   3.4                   1.5
# 4.4                                   2.9                   1.4
# 4.9                                   3.1                   1.5
# 5.4                                   3.7                   1.5
# 4.8                                   3.4                   1.6
# 4.8                                   3.0                   1.4
# 4.3                                   3.0                   1.1
# 5.8                                   4.0                   1.2
# 5.7                                   4.4                   1.5
# 5.4                                   3.9                   1.3
# 5.1                                   3.5                   1.4
# 5.7                                   3.8                   1.7
# 5.1                                   3.8                   1.5
# 5.4                                   3.4                   1.7
# 5.1                                   3.7                   1.5
# 4.6                                   3.6                   1.0
# 5.1                                   3.3                   1.7
# 4.8                                   3.4                   1.9
# 5.0                                   3.0                   1.6
# 5.0                                   3.4                   1.6
# 5.2                                   3.5                   1.5
# 5.2                                   3.4                   1.4
# 4.7                                   3.2                   1.6
# ...                                   ...                   ...
# 6.9                                   3.2                   5.7
# 5.6                                   2.8                   4.9
# 7.7                                   2.8                   6.7
# 6.3                                   2.7                   4.9
# 6.7                                   3.3                   5.7
# 7.2                                   3.2                   6.0
# 6.2                                   2.8                   4.8
# 6.1                                   3.0                   4.9
# 6.4                                   2.8                   5.6
# 7.2                                   3.0                   5.8
# 7.4                                   2.8                   6.1
# 7.9                                   3.8                   6.4
# 6.4                                   2.8                   5.6
# 6.3                                   2.8                   5.1
# 6.1                                   2.6                   5.6
# 7.7                                   3.0                   6.1
# 6.3                                   3.4                   5.6
# 6.4                                   3.1                   5.5
# 6.0                                   3.0                   4.8
# 6.9                                   3.1                   5.4
# 6.7                                   3.1                   5.6
# 6.9                                   3.1                   5.1
# 5.8                                   2.7                   5.1
# 6.8                                   3.2                   5.9
# 6.7                                   3.3                   5.7
# 6.7                                   3.0                   5.2
# 6.3                                   2.5                   5.0
# 6.5                                   3.0                   5.2
# 6.2                                   3.4                   5.4
# 5.9                                   3.0                   5.1
#
#                       Petal width (in cm)           Class
# Sepal Length (in cm)
# 5.1                                   0.2     Iris-setosa
# 4.9                                   0.2     Iris-setosa
# 4.7                                   0.2     Iris-setosa
# 4.6                                   0.2     Iris-setosa
# 5.0                                   0.2     Iris-setosa
# 5.4                                   0.4     Iris-setosa
# 4.6                                   0.3     Iris-setosa
# 5.0                                   0.2     Iris-setosa
# 4.4                                   0.2     Iris-setosa
# 4.9                                   0.1     Iris-setosa
# 5.4                                   0.2     Iris-setosa
# 4.8                                   0.2     Iris-setosa
# 4.8                                   0.1     Iris-setosa
# 4.3                                   0.1     Iris-setosa
# 5.8                                   0.2     Iris-setosa
# 5.7                                   0.4     Iris-setosa
# 5.4                                   0.4     Iris-setosa
# 5.1                                   0.3     Iris-setosa
# 5.7                                   0.3     Iris-setosa
# 5.1                                   0.3     Iris-setosa
# 5.4                                   0.2     Iris-setosa
# 5.1                                   0.4     Iris-setosa
# 4.6                                   0.2     Iris-setosa
# 5.1                                   0.5     Iris-setosa
# 4.8                                   0.2     Iris-setosa
# 5.0                                   0.2     Iris-setosa
# 5.0                                   0.4     Iris-setosa
# 5.2                                   0.2     Iris-setosa
# 5.2                                   0.2     Iris-setosa
# 4.7                                   0.2     Iris-setosa
# ...                                   ...             ...
# 6.9                                   2.3  Iris-virginica
# 5.6                                   2.0  Iris-virginica
# 7.7                                   2.0  Iris-virginica
# 6.3                                   1.8  Iris-virginica
# 6.7                                   2.1  Iris-virginica
# 7.2                                   1.8  Iris-virginica
# 6.2                                   1.8  Iris-virginica
# 6.1                                   1.8  Iris-virginica
# 6.4                                   2.1  Iris-virginica
# 7.2                                   1.6  Iris-virginica
# 7.4                                   1.9  Iris-virginica
# 7.9                                   2.0  Iris-virginica
# 6.4                                   2.2  Iris-virginica
# 6.3                                   1.5  Iris-virginica
# 6.1                                   1.4  Iris-virginica
# 7.7                                   2.3  Iris-virginica
# 6.3                                   2.4  Iris-virginica
# 6.4                                   1.8  Iris-virginica
# 6.0                                   1.8  Iris-virginica
# 6.9                                   2.1  Iris-virginica
# 6.7                                   2.4  Iris-virginica
# 6.9                                   2.3  Iris-virginica
# 5.8                                   1.9  Iris-virginica
# 6.8                                   2.3  Iris-virginica
# 6.7                                   2.5  Iris-virginica
# 6.7                                   2.3  Iris-virginica
# 6.3                                   1.9  Iris-virginica
# 6.5                                   2.0  Iris-virginica
# 6.2                                   2.3  Iris-virginica
# 5.9                                   1.8  Iris-virginica
#
# [150 rows x 4 columns]

# %% [markdown]
# ### Use Iloc function to print all the rows of the 3rd column

# %%
iris.iloc[:,2:3]
# Out:
#      Petal length (in cm)
# 0                     1.4
# 1                     1.4
# 2                     1.3
# 3                     1.5
# 4                     1.4
# 5                     1.7
# 6                     1.4
# 7                     1.5
# 8                     1.4
# 9                     1.5
# 10                    1.5
# 11                    1.6
# 12                    1.4
# 13                    1.1
# 14                    1.2
# 15                    1.5
# 16                    1.3
# 17                    1.4
# 18                    1.7
# 19                    1.5
# 20                    1.7
# 21                    1.5
# 22                    1.0
# 23                    1.7
# 24                    1.9
# 25                    1.6
# 26                    1.6
# 27                    1.5
# 28                    1.4
# 29                    1.6
# ..                    ...
# 120                   5.7
# 121                   4.9
# 122                   6.7
# 123                   4.9
# 124                   5.7
# 125                   6.0
# 126                   4.8
# 127                   4.9
# 128                   5.6
# 129                   5.8
# 130                   6.1
# 131                   6.4
# 132                   5.6
# 133                   5.1
# 134                   5.6
# 135                   6.1
# 136                   5.6
# 137                   5.5
# 138                   4.8
# 139                   5.4
# 140                   5.6
# 141                   5.1
# 142                   5.1
# 143                   5.9
# 144                   5.7
# 145                   5.2
# 146                   5.0
# 147                   5.2
# 148                   5.4
# 149                   5.1
#
# [150 rows x 1 columns]

# %% [markdown]
# ### Slicing
# Print only the Sepal width and Sepal Length for first 10 rows

# %%
iris.iloc[:10,:2]
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)
# 0                   5.1                  3.5
# 1                   4.9                  3.0
# 2                   4.7                  3.2
# 3                   4.6                  3.1
# 4                   5.0                  3.6
# 5                   5.4                  3.9
# 6                   4.6                  3.4
# 7                   5.0                  3.4
# 8                   4.4                  2.9
# 9                   4.9                  3.1

# %% [markdown]
# ### Using Logical statements for indexing
# Print all the columns of row which has class name "Iris-setosa"

# %%
for i in range(len(iris)):
    if (iris['Class'][i]=="Iris-setosa"):
        print(iris.loc[i,:])
# Out:
# Sepal Length (in cm)            5.1
# Sepal Width in (cm)             3.5
# Petal length (in cm)            1.4
# Petal width (in cm)             0.2
# Class                   Iris-setosa
# SepalExtra                    17.85
# Name: 0, dtype: object
# Sepal Length (in cm)            4.9
# Sepal Width in (cm)               3
# Petal length (in cm)            1.4
# Petal width (in cm)             0.2
# Class                   Iris-setosa
# SepalExtra                     14.7
# Name: 1, dtype: object
# Sepal Length (in cm)            4.7
# Sepal Width in (cm)             3.2
# Petal length (in cm)            1.3
# Petal width (in cm)             0.2
# Class                   Iris-setosa
# SepalExtra                    15.04
# Name: 2, dtype: object
# Sepal Length (in cm)            4.6
# Sepal Width in (cm)             3.1
# Petal length (in cm)            1.5
# Petal width (in cm)             0.2
# Class                   Iris-setosa
# SepalExtra                    14.26
# Name: 3, dtype: object
# Sepal Length (in cm)              5
# Sepal Width in (cm)             3.6
# Petal length (in cm)            1.4
# Petal width (in cm)             0.2
# Class                   Iris-setosa
# SepalExtra                       18
# Name: 4, dtype: object
# Sepal Length (in cm)            5.4
# Sepal Width in (cm)             3.9
# Petal length (in cm)            1.7
# Petal width (in cm)             0.4
# Class                   Iris-setosa
# SepalExtra                    21.06
# Name: 5, dtype: object
# Sepal Length (in cm)            4.6
# Sepal Width in (cm)             3.4
# Petal length (in cm)            1.4
# Petal width (in cm)             0.3
# Class                   Iris-setosa
# SepalExtra                    15.64
# Name: 6, dtype: object
# Sepal Length (in cm)              5
# Sepal Width in (cm)             3.4
# Petal length (in cm)            1.5
# Petal width (in cm)             0.2
# Class                   Iris-setosa
# SepalExtra                       17
# Name: 7, dtype: object
# Sepal Length (in cm)            4.4
# Sepal Width in (cm)             2.9
# Petal length (in cm)            1.4
# Petal width (in cm)             0.2
# Class                   Iris-setosa
# SepalExtra                    12.76
# Name: 8, dtype: object
# Sepal Length (in cm)            4.9
# Sepal Width in (cm)             3.1
# Petal length (in cm)            1.5
# Petal width (in cm)             0.1
# Class                   Iris-setosa
# SepalExtra                    15.19
# Name: 9, dtype: object
# Sepal Length (in cm)            5.4
# Sepal Width in (cm)             3.7
# Petal length (in cm)            1.5
# Petal width (in cm)             0.2
# Class                   Iris-setosa
# SepalExtra                    19.98
# Name: 10, dtype: object
# Sepal Length (in cm)            4.8
# Sepal Width in (cm)             3.4
# Petal length (in cm)            1.6
# Petal width (in cm)             0.2
# Class                   Iris-setosa
# SepalExtra                    16.32
# Name: 11, dtype: object
# Sepal Length (in cm)            4.8
# Sepal Width in (cm)               3
# Petal length (in cm)            1.4
# Petal width (in cm)             0.1
# Class                   Iris-setosa
# SepalExtra                     14.4
# Name: 12, dtype: object
# Sepal Length (in cm)            4.3
# Sepal Width in (cm)               3
# Petal length (in cm)            1.1
# Petal width (in cm)             0.1
# Class                   Iris-setosa
# SepalExtra                     12.9
# Name: 13, dtype: object
# Sepal Length (in cm)            5.8
# Sepal Width in (cm)               4
# Petal length (in cm)            1.2
# Petal width (in cm)             0.2
# Class                   Iris-setosa
# SepalExtra                     23.2
# Name: 14, dtype: object
# Sepal Length (in cm)            5.7
# Sepal Width in (cm)             4.4
# Petal length (in cm)            1.5
# Petal width (in cm)             0.4
# Class                   Iris-setosa
# SepalExtra                    25.08
# Name: 15, dtype: object
# Sepal Length (in cm)            5.4
# Sepal Width in (cm)             3.9
# Petal length (in cm)            1.3
# Petal width (in cm)             0.4
# Class                   Iris-setosa
# SepalExtra                    21.06
# Name: 16, dtype: object
# Sepal Length (in cm)            5.1
# Sepal Width in (cm)             3.5
# Petal length (in cm)            1.4
# Petal width (in cm)             0.3
# Class                   Iris-setosa
# SepalExtra                    17.85
# Name: 17, dtype: object
# Sepal Length (in cm)            5.7
# Sepal Width in (cm)             3.8
# Petal length (in cm)            1.7
# Petal width (in cm)             0.3
# Class                   Iris-setosa
# SepalExtra                    21.66
# Name: 18, dtype: object
# Sepal Length (in cm)            5.1
# Sepal Width in (cm)             3.8
# Petal length (in cm)            1.5
# Petal width (in cm)             0.3
# Class                   Iris-setosa
# SepalExtra                    19.38
# Name: 19, dtype: object
# Sepal Length (in cm)            5.4
# Sepal Width in (cm)             3.4
# Petal length (in cm)            1.7
# Petal width (in cm)             0.2
# Class                   Iris-setosa
# SepalExtra                    18.36
# Name: 20, dtype: object
# Sepal Length (in cm)            5.1
# Sepal Width in (cm)             3.7
# Petal length (in cm)            1.5
# Petal width (in cm)             0.4
# Class                   Iris-setosa
# SepalExtra                    18.87
# Name: 21, dtype: object
# Sepal Length (in cm)            4.6
# Sepal Width in (cm)             3.6
# Petal length (in cm)              1
# Petal width (in cm)             0.2
# Class                   Iris-setosa
# SepalExtra                    16.56
# Name: 22, dtype: object
# Sepal Length (in cm)            5.1
# Sepal Width in (cm)             3.3
# Petal length (in cm)            1.7
# Petal width (in cm)             0.5
# Class                   Iris-setosa
# SepalExtra                    16.83
# Name: 23, dtype: object
# Sepal Length (in cm)            4.8
# Sepal Width in (cm)             3.4
# Petal length (in cm)            1.9
# Petal width (in cm)             0.2
# Class                   Iris-setosa
# SepalExtra                    16.32
# Name: 24, dtype: object
# Sepal Length (in cm)              5
# Sepal Width in (cm)               3
# Petal length (in cm)            1.6
# Petal width (in cm)             0.2
# Class                   Iris-setosa
# SepalExtra                       15
# Name: 25, dtype: object
# Sepal Length (in cm)              5
# Sepal Width in (cm)             3.4
# Petal length (in cm)            1.6
# Petal width (in cm)             0.4
# Class                   Iris-setosa
# SepalExtra                       17
# Name: 26, dtype: object
# Sepal Length (in cm)            5.2
# Sepal Width in (cm)             3.5
# Petal length (in cm)            1.5
# Petal width (in cm)             0.2
# Class                   Iris-setosa
# SepalExtra                     18.2
# Name: 27, dtype: object
# Sepal Length (in cm)            5.2
# Sepal Width in (cm)             3.4
# Petal length (in cm)            1.4
# Petal width (in cm)             0.2
# Class                   Iris-setosa
# SepalExtra                    17.68
# Name: 28, dtype: object
# Sepal Length (in cm)            4.7
# Sepal Width in (cm)             3.2
# Petal length (in cm)            1.6
# Petal width (in cm)             0.2
# Class                   Iris-setosa
# SepalExtra                    15.04
# Name: 29, dtype: object
# Sepal Length (in cm)            4.8
# Sepal Width in (cm)             3.1
# Petal length (in cm)            1.6
# Petal width (in cm)             0.2
# Class                   Iris-setosa
# SepalExtra                    14.88
# Name: 30, dtype: object
# Sepal Length (in cm)            5.4
# Sepal Width in (cm)             3.4
# Petal length (in cm)            1.5
# Petal width (in cm)             0.4
# Class                   Iris-setosa
# SepalExtra                    18.36
# Name: 31, dtype: object
# Sepal Length (in cm)            5.2
# Sepal Width in (cm)             4.1
# Petal length (in cm)            1.5
# Petal width (in cm)             0.1
# Class                   Iris-setosa
# SepalExtra                    21.32
# Name: 32, dtype: object
# Sepal Length (in cm)            5.5
# Sepal Width in (cm)             4.2
# Petal length (in cm)            1.4
# Petal width (in cm)             0.2
# Class                   Iris-setosa
# SepalExtra                     23.1
# Name: 33, dtype: object
# Sepal Length (in cm)            4.9
# Sepal Width in (cm)             3.1
# Petal length (in cm)            1.5
# Petal width (in cm)             0.1
# Class                   Iris-setosa
# SepalExtra                    15.19
# Name: 34, dtype: object
# Sepal Length (in cm)              5
# Sepal Width in (cm)             3.2
# Petal length (in cm)            1.2
# Petal width (in cm)             0.2
# Class                   Iris-setosa
# SepalExtra                       16
# Name: 35, dtype: object
# Sepal Length (in cm)            5.5
# Sepal Width in (cm)             3.5
# Petal length (in cm)            1.3
# Petal width (in cm)             0.2
# Class                   Iris-setosa
# SepalExtra                    19.25
# Name: 36, dtype: object
# Sepal Length (in cm)            4.9
# Sepal Width in (cm)             3.1
# Petal length (in cm)            1.5
# Petal width (in cm)             0.1
# Class                   Iris-setosa
# SepalExtra                    15.19
# Name: 37, dtype: object
# Sepal Length (in cm)            4.4
# Sepal Width in (cm)               3
# Petal length (in cm)            1.3
# Petal width (in cm)             0.2
# Class                   Iris-setosa
# SepalExtra                     13.2
# Name: 38, dtype: object
# Sepal Length (in cm)            5.1
# Sepal Width in (cm)             3.4
# Petal length (in cm)            1.5
# Petal width (in cm)             0.2
# Class                   Iris-setosa
# SepalExtra                    17.34
# Name: 39, dtype: object
# Sepal Length (in cm)              5
# Sepal Width in (cm)             3.5
# Petal length (in cm)            1.3
# Petal width (in cm)             0.3
# Class                   Iris-setosa
# SepalExtra                     17.5
# Name: 40, dtype: object
# Sepal Length (in cm)            4.5
# Sepal Width in (cm)             2.3
# Petal length (in cm)            1.3
# Petal width (in cm)             0.3
# Class                   Iris-setosa
# SepalExtra                    10.35
# Name: 41, dtype: object
# Sepal Length (in cm)            4.4
# Sepal Width in (cm)             3.2
# Petal length (in cm)            1.3
# Petal width (in cm)             0.2
# Class                   Iris-setosa
# SepalExtra                    14.08
# Name: 42, dtype: object
# Sepal Length (in cm)              5
# Sepal Width in (cm)             3.5
# Petal length (in cm)            1.6
# Petal width (in cm)             0.6
# Class                   Iris-setosa
# SepalExtra                     17.5
# Name: 43, dtype: object
# Sepal Length (in cm)            5.1
# Sepal Width in (cm)             3.8
# Petal length (in cm)            1.9
# Petal width (in cm)             0.4
# Class                   Iris-setosa
# SepalExtra                    19.38
# Name: 44, dtype: object
# Sepal Length (in cm)            4.8
# Sepal Width in (cm)               3
# Petal length (in cm)            1.4
# Petal width (in cm)             0.3
# Class                   Iris-setosa
# SepalExtra                     14.4
# Name: 45, dtype: object
# Sepal Length (in cm)            5.1
# Sepal Width in (cm)             3.8
# Petal length (in cm)            1.6
# Petal width (in cm)             0.2
# Class                   Iris-setosa
# SepalExtra                    19.38
# Name: 46, dtype: object
# Sepal Length (in cm)            4.6
# Sepal Width in (cm)             3.2
# Petal length (in cm)            1.4
# Petal width (in cm)             0.2
# Class                   Iris-setosa
# SepalExtra                    14.72
# Name: 47, dtype: object
# Sepal Length (in cm)            5.3
# Sepal Width in (cm)             3.7
# Petal length (in cm)            1.5
# Petal width (in cm)             0.2
# Class                   Iris-setosa
# SepalExtra                    19.61
# Name: 48, dtype: object
# Sepal Length (in cm)              5
# Sepal Width in (cm)             3.3
# Petal length (in cm)            1.4
# Petal width (in cm)             0.2
# Class                   Iris-setosa
# SepalExtra                     16.5
# Name: 49, dtype: object

# %% [markdown]
# ### Multiply Sepal Length and width and store it under the column name "SepalExtra" in the same Iris dataframe

# %%
iris['SepalExtra']=iris['Sepal Length (in cm)']*iris['Sepal Width in (cm)']
print(iris)
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                     5.1                  3.5                   1.4
# 1                     4.9                  3.0                   1.4
# 2                     4.7                  3.2                   1.3
# 3                     4.6                  3.1                   1.5
# 4                     5.0                  3.6                   1.4
# 5                     5.4                  3.9                   1.7
# 6                     4.6                  3.4                   1.4
# 7                     5.0                  3.4                   1.5
# 8                     4.4                  2.9                   1.4
# 9                     4.9                  3.1                   1.5
# 10                    5.4                  3.7                   1.5
# 11                    4.8                  3.4                   1.6
# 12                    4.8                  3.0                   1.4
# 13                    4.3                  3.0                   1.1
# 14                    5.8                  4.0                   1.2
# 15                    5.7                  4.4                   1.5
# 16                    5.4                  3.9                   1.3
# 17                    5.1                  3.5                   1.4
# 18                    5.7                  3.8                   1.7
# 19                    5.1                  3.8                   1.5
# 20                    5.4                  3.4                   1.7
# 21                    5.1                  3.7                   1.5
# 22                    4.6                  3.6                   1.0
# 23                    5.1                  3.3                   1.7
# 24                    4.8                  3.4                   1.9
# 25                    5.0                  3.0                   1.6
# 26                    5.0                  3.4                   1.6
# 27                    5.2                  3.5                   1.5
# 28                    5.2                  3.4                   1.4
# 29                    4.7                  3.2                   1.6
# ..                    ...                  ...                   ...
# 120                   6.9                  3.2                   5.7
# 121                   5.6                  2.8                   4.9
# 122                   7.7                  2.8                   6.7
# 123                   6.3                  2.7                   4.9
# 124                   6.7                  3.3                   5.7
# 125                   7.2                  3.2                   6.0
# 126                   6.2                  2.8                   4.8
# 127                   6.1                  3.0                   4.9
# 128                   6.4                  2.8                   5.6
# 129                   7.2                  3.0                   5.8
# 130                   7.4                  2.8                   6.1
# 131                   7.9                  3.8                   6.4
# 132                   6.4                  2.8                   5.6
# 133                   6.3                  2.8                   5.1
# 134                   6.1                  2.6                   5.6
# 135                   7.7                  3.0                   6.1
# 136                   6.3                  3.4                   5.6
# 137                   6.4                  3.1                   5.5
# 138                   6.0                  3.0                   4.8
# 139                   6.9                  3.1                   5.4
# 140                   6.7                  3.1                   5.6
# 141                   6.9                  3.1                   5.1
# 142                   5.8                  2.7                   5.1
# 143                   6.8                  3.2                   5.9
# 144                   6.7                  3.3                   5.7
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class  SepalExtra
# 0                    0.2     Iris-setosa       17.85
# 1                    0.2     Iris-setosa       14.70
# 2                    0.2     Iris-setosa       15.04
# 3                    0.2     Iris-setosa       14.26
# 4                    0.2     Iris-setosa       18.00
# 5                    0.4     Iris-setosa       21.06
# 6                    0.3     Iris-setosa       15.64
# 7                    0.2     Iris-setosa       17.00
# 8                    0.2     Iris-setosa       12.76
# 9                    0.1     Iris-setosa       15.19
# 10                   0.2     Iris-setosa       19.98
# 11                   0.2     Iris-setosa       16.32
# 12                   0.1     Iris-setosa       14.40
# 13                   0.1     Iris-setosa       12.90
# 14                   0.2     Iris-setosa       23.20
# 15                   0.4     Iris-setosa       25.08
# 16                   0.4     Iris-setosa       21.06
# 17                   0.3     Iris-setosa       17.85
# 18                   0.3     Iris-setosa       21.66
# 19                   0.3     Iris-setosa       19.38
# 20                   0.2     Iris-setosa       18.36
# 21                   0.4     Iris-setosa       18.87
# 22                   0.2     Iris-setosa       16.56
# 23                   0.5     Iris-setosa       16.83
# 24                   0.2     Iris-setosa       16.32
# 25                   0.2     Iris-setosa       15.00
# 26                   0.4     Iris-setosa       17.00
# 27                   0.2     Iris-setosa       18.20
# 28                   0.2     Iris-setosa       17.68
# 29                   0.2     Iris-setosa       15.04
# ..                   ...             ...         ...
# 120                  2.3  Iris-virginica       22.08
# 121                  2.0  Iris-virginica       15.68
# 122                  2.0  Iris-virginica       21.56
# 123                  1.8  Iris-virginica       17.01
# 124                  2.1  Iris-virginica       22.11
# 125                  1.8  Iris-virginica       23.04
# 126                  1.8  Iris-virginica       17.36
# 127                  1.8  Iris-virginica       18.30
# 128                  2.1  Iris-virginica       17.92
# 129                  1.6  Iris-virginica       21.60
# 130                  1.9  Iris-virginica       20.72
# 131                  2.0  Iris-virginica       30.02
# 132                  2.2  Iris-virginica       17.92
# 133                  1.5  Iris-virginica       17.64
# 134                  1.4  Iris-virginica       15.86
# 135                  2.3  Iris-virginica       23.10
# 136                  2.4  Iris-virginica       21.42
# 137                  1.8  Iris-virginica       19.84
# 138                  1.8  Iris-virginica       18.00
# 139                  2.1  Iris-virginica       21.39
# 140                  2.4  Iris-virginica       20.77
# 141                  2.3  Iris-virginica       21.39
# 142                  1.9  Iris-virginica       15.66
# 143                  2.3  Iris-virginica       21.76
# 144                  2.5  Iris-virginica       22.11
# 145                  2.3  Iris-virginica       20.10
# 146                  1.9  Iris-virginica       15.75
# 147                  2.0  Iris-virginica       19.50
# 148                  2.3  Iris-virginica       21.08
# 149                  1.8  Iris-virginica       17.70
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Find out the mean and variance for each column but for class column

# %%
iris.describe()
# Out:
#        Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# count            150.000000           150.000000            150.000000
# mean               5.843333             3.054000              3.758667
# std                0.828066             0.433594              1.764420
# min                4.300000             2.000000              1.000000
# 25%                5.100000             2.800000              1.600000
# 50%                5.800000             3.000000              4.350000
# 75%                6.400000             3.300000              5.100000
# max                7.900000             4.400000              6.900000
#
#        Petal width (in cm)  SepalExtra
# count           150.000000  150.000000
# mean              1.198667   17.806533
# std               0.763161    3.368693
# min               0.100000   10.000000
# 25%               0.300000   15.645000
# 50%               1.300000   17.660000
# 75%               1.800000   20.325000
# max               2.500000   30.020000

# %% [markdown]
# ### Write a function that accepts two numbers as input and prints them - Pass the Sepal length and sepal width of 5th row and print the output

# %%
def my_method(num1,num2):
    print("The numbers you have passed are :"+str(num1)+ " & "+str(num2))
my_method(iris.loc[5,'Sepal Length (in cm)'],iris.loc[5,'Sepal Width in (cm)'])
# Out:
# The numbers you have passed are :5.4 & 3.9

# %% [markdown]
# ### Find the range of all the columns in the dataset
#
# *Range = Max value - Min value (in the column)*

# %%
Range_SepalLength=iris['Sepal Length (in cm)'].max()-iris['Sepal Length (in cm)'].min()
Range_SepalWidth=iris['Sepal Width in (cm)'].max()-iris['Sepal Width in (cm)'].min()
Range_Petallength=iris['Petal length (in cm)'].max()-iris['Petal length (in cm)'].min()
Range_Petalwidth=iris['Petal width (in cm)'].max()-iris['Petal width (in cm)'].min()
Range_SepalExtra=iris['SepalExtra'].max()-iris['SepalExtra'].min()
print(Range_SepalLength,Range_SepalWidth,Range_Petallength,Range_Petalwidth,Range_SepalExtra)
# Out:
# 3.6000000000000005 2.4000000000000004 5.9 2.4 20.02

# %% [markdown]
# ### Sort the entire dataset according to the column Petal width

# %%
iris.sort_values(["Petal width (in cm)"],ascending=False)
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 100                   6.3                  3.3                   6.0
# 109                   7.2                  3.6                   6.1
# 144                   6.7                  3.3                   5.7
# 114                   5.8                  2.8                   5.1
# 140                   6.7                  3.1                   5.6
# 136                   6.3                  3.4                   5.6
# 148                   6.2                  3.4                   5.4
# 115                   6.4                  3.2                   5.3
# 145                   6.7                  3.0                   5.2
# 143                   6.8                  3.2                   5.9
# 141                   6.9                  3.1                   5.1
# 120                   6.9                  3.2                   5.7
# 118                   7.7                  2.6                   6.9
# 135                   7.7                  3.0                   6.1
# 104                   6.5                  3.0                   5.8
# 132                   6.4                  2.8                   5.6
# 117                   7.7                  3.8                   6.7
# 102                   7.1                  3.0                   5.9
# 124                   6.7                  3.3                   5.7
# 112                   6.8                  3.0                   5.5
# 139                   6.9                  3.1                   5.4
# 128                   6.4                  2.8                   5.6
# 105                   7.6                  3.0                   6.6
# 121                   5.6                  2.8                   4.9
# 110                   6.5                  3.2                   5.1
# 122                   7.7                  2.8                   6.7
# 131                   7.9                  3.8                   6.4
# 147                   6.5                  3.0                   5.2
# 113                   5.7                  2.5                   5.0
# 130                   7.4                  2.8                   6.1
# ..                    ...                  ...                   ...
# 14                    5.8                  4.0                   1.2
# 11                    4.8                  3.4                   1.6
# 8                     4.4                  2.9                   1.4
# 42                    4.4                  3.2                   1.3
# 7                     5.0                  3.4                   1.5
# 49                    5.0                  3.3                   1.4
# 1                     4.9                  3.0                   1.4
# 4                     5.0                  3.6                   1.4
# 3                     4.6                  3.1                   1.5
# 2                     4.7                  3.2                   1.3
# 35                    5.0                  3.2                   1.2
# 36                    5.5                  3.5                   1.3
# 20                    5.4                  3.4                   1.7
# 27                    5.2                  3.5                   1.5
# 33                    5.5                  4.2                   1.4
# 30                    4.8                  3.1                   1.6
# 29                    4.7                  3.2                   1.6
# 28                    5.2                  3.4                   1.4
# 22                    4.6                  3.6                   1.0
# 0                     5.1                  3.5                   1.4
# 38                    4.4                  3.0                   1.3
# 25                    5.0                  3.0                   1.6
# 24                    4.8                  3.4                   1.9
# 39                    5.1                  3.4                   1.5
# 12                    4.8                  3.0                   1.4
# 13                    4.3                  3.0                   1.1
# 37                    4.9                  3.1                   1.5
# 32                    5.2                  4.1                   1.5
# 34                    4.9                  3.1                   1.5
# 9                     4.9                  3.1                   1.5
#
#      Petal width (in cm)           Class  SepalExtra
# 100                  2.5  Iris-virginica       20.79
# 109                  2.5  Iris-virginica       25.92
# 144                  2.5  Iris-virginica       22.11
# 114                  2.4  Iris-virginica       16.24
# 140                  2.4  Iris-virginica       20.77
# 136                  2.4  Iris-virginica       21.42
# 148                  2.3  Iris-virginica       21.08
# 115                  2.3  Iris-virginica       20.48
# 145                  2.3  Iris-virginica       20.10
# 143                  2.3  Iris-virginica       21.76
# 141                  2.3  Iris-virginica       21.39
# 120                  2.3  Iris-virginica       22.08
# 118                  2.3  Iris-virginica       20.02
# 135                  2.3  Iris-virginica       23.10
# 104                  2.2  Iris-virginica       19.50
# 132                  2.2  Iris-virginica       17.92
# 117                  2.2  Iris-virginica       29.26
# 102                  2.1  Iris-virginica       21.30
# 124                  2.1  Iris-virginica       22.11
# 112                  2.1  Iris-virginica       20.40
# 139                  2.1  Iris-virginica       21.39
# 128                  2.1  Iris-virginica       17.92
# 105                  2.1  Iris-virginica       22.80
# 121                  2.0  Iris-virginica       15.68
# 110                  2.0  Iris-virginica       20.80
# 122                  2.0  Iris-virginica       21.56
# 131                  2.0  Iris-virginica       30.02
# 147                  2.0  Iris-virginica       19.50
# 113                  2.0  Iris-virginica       14.25
# 130                  1.9  Iris-virginica       20.72
# ..                   ...             ...         ...
# 14                   0.2     Iris-setosa       23.20
# 11                   0.2     Iris-setosa       16.32
# 8                    0.2     Iris-setosa       12.76
# 42                   0.2     Iris-setosa       14.08
# 7                    0.2     Iris-setosa       17.00
# 49                   0.2     Iris-setosa       16.50
# 1                    0.2     Iris-setosa       14.70
# 4                    0.2     Iris-setosa       18.00
# 3                    0.2     Iris-setosa       14.26
# 2                    0.2     Iris-setosa       15.04
# 35                   0.2     Iris-setosa       16.00
# 36                   0.2     Iris-setosa       19.25
# 20                   0.2     Iris-setosa       18.36
# 27                   0.2     Iris-setosa       18.20
# 33                   0.2     Iris-setosa       23.10
# 30                   0.2     Iris-setosa       14.88
# 29                   0.2     Iris-setosa       15.04
# 28                   0.2     Iris-setosa       17.68
# 22                   0.2     Iris-setosa       16.56
# 0                    0.2     Iris-setosa       17.85
# 38                   0.2     Iris-setosa       13.20
# 25                   0.2     Iris-setosa       15.00
# 24                   0.2     Iris-setosa       16.32
# 39                   0.2     Iris-setosa       17.34
# 12                   0.1     Iris-setosa       14.40
# 13                   0.1     Iris-setosa       12.90
# 37                   0.1     Iris-setosa       15.19
# 32                   0.1     Iris-setosa       21.32
# 34                   0.1     Iris-setosa       15.19
# 9                    0.1     Iris-setosa       15.19
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Remove the new column "SepalExtra" from the dataframe

# %%
iris.drop('SepalExtra',axis=1)
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                     5.1                  3.5                   1.4
# 1                     4.9                  3.0                   1.4
# 2                     4.7                  3.2                   1.3
# 3                     4.6                  3.1                   1.5
# 4                     5.0                  3.6                   1.4
# 5                     5.4                  3.9                   1.7
# 6                     4.6                  3.4                   1.4
# 7                     5.0                  3.4                   1.5
# 8                     4.4                  2.9                   1.4
# 9                     4.9                  3.1                   1.5
# 10                    5.4                  3.7                   1.5
# 11                    4.8                  3.4                   1.6
# 12                    4.8                  3.0                   1.4
# 13                    4.3                  3.0                   1.1
# 14                    5.8                  4.0                   1.2
# 15                    5.7                  4.4                   1.5
# 16                    5.4                  3.9                   1.3
# 17                    5.1                  3.5                   1.4
# 18                    5.7                  3.8                   1.7
# 19                    5.1                  3.8                   1.5
# 20                    5.4                  3.4                   1.7
# 21                    5.1                  3.7                   1.5
# 22                    4.6                  3.6                   1.0
# 23                    5.1                  3.3                   1.7
# 24                    4.8                  3.4                   1.9
# 25                    5.0                  3.0                   1.6
# 26                    5.0                  3.4                   1.6
# 27                    5.2                  3.5                   1.5
# 28                    5.2                  3.4                   1.4
# 29                    4.7                  3.2                   1.6
# ..                    ...                  ...                   ...
# 120                   6.9                  3.2                   5.7
# 121                   5.6                  2.8                   4.9
# 122                   7.7                  2.8                   6.7
# 123                   6.3                  2.7                   4.9
# 124                   6.7                  3.3                   5.7
# 125                   7.2                  3.2                   6.0
# 126                   6.2                  2.8                   4.8
# 127                   6.1                  3.0                   4.9
# 128                   6.4                  2.8                   5.6
# 129                   7.2                  3.0                   5.8
# 130                   7.4                  2.8                   6.1
# 131                   7.9                  3.8                   6.4
# 132                   6.4                  2.8                   5.6
# 133                   6.3                  2.8                   5.1
# 134                   6.1                  2.6                   5.6
# 135                   7.7                  3.0                   6.1
# 136                   6.3                  3.4                   5.6
# 137                   6.4                  3.1                   5.5
# 138                   6.0                  3.0                   4.8
# 139                   6.9                  3.1                   5.4
# 140                   6.7                  3.1                   5.6
# 141                   6.9                  3.1                   5.1
# 142                   5.8                  2.7                   5.1
# 143                   6.8                  3.2                   5.9
# 144                   6.7                  3.3                   5.7
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 0                    0.2     Iris-setosa
# 1                    0.2     Iris-setosa
# 2                    0.2     Iris-setosa
# 3                    0.2     Iris-setosa
# 4                    0.2     Iris-setosa
# 5                    0.4     Iris-setosa
# 6                    0.3     Iris-setosa
# 7                    0.2     Iris-setosa
# 8                    0.2     Iris-setosa
# 9                    0.1     Iris-setosa
# 10                   0.2     Iris-setosa
# 11                   0.2     Iris-setosa
# 12                   0.1     Iris-setosa
# 13                   0.1     Iris-setosa
# 14                   0.2     Iris-setosa
# 15                   0.4     Iris-setosa
# 16                   0.4     Iris-setosa
# 17                   0.3     Iris-setosa
# 18                   0.3     Iris-setosa
# 19                   0.3     Iris-setosa
# 20                   0.2     Iris-setosa
# 21                   0.4     Iris-setosa
# 22                   0.2     Iris-setosa
# 23                   0.5     Iris-setosa
# 24                   0.2     Iris-setosa
# 25                   0.2     Iris-setosa
# 26                   0.4     Iris-setosa
# 27                   0.2     Iris-setosa
# 28                   0.2     Iris-setosa
# 29                   0.2     Iris-setosa
# ..                   ...             ...
# 120                  2.3  Iris-virginica
# 121                  2.0  Iris-virginica
# 122                  2.0  Iris-virginica
# 123                  1.8  Iris-virginica
# 124                  2.1  Iris-virginica
# 125                  1.8  Iris-virginica
# 126                  1.8  Iris-virginica
# 127                  1.8  Iris-virginica
# 128                  2.1  Iris-virginica
# 129                  1.6  Iris-virginica
# 130                  1.9  Iris-virginica
# 131                  2.0  Iris-virginica
# 132                  2.2  Iris-virginica
# 133                  1.5  Iris-virginica
# 134                  1.4  Iris-virginica
# 135                  2.3  Iris-virginica
# 136                  2.4  Iris-virginica
# 137                  1.8  Iris-virginica
# 138                  1.8  Iris-virginica
# 139                  2.1  Iris-virginica
# 140                  2.4  Iris-virginica
# 141                  2.3  Iris-virginica
# 142                  1.9  Iris-virginica
# 143                  2.3  Iris-virginica
# 144                  2.5  Iris-virginica
# 145                  2.3  Iris-virginica
# 146                  1.9  Iris-virginica
# 147                  2.0  Iris-virginica
# 148                  2.3  Iris-virginica
# 149                  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Print only the rows which has the class to be "Iris-setosa"

# %%
filtered_data = iris[iris["Class"]=="Iris-setosa"]
print(filtered_data)
# Out:
#     Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                    5.1                  3.5                   1.4
# 1                    4.9                  3.0                   1.4
# 2                    4.7                  3.2                   1.3
# 3                    4.6                  3.1                   1.5
# 4                    5.0                  3.6                   1.4
# 5                    5.4                  3.9                   1.7
# 6                    4.6                  3.4                   1.4
# 7                    5.0                  3.4                   1.5
# 8                    4.4                  2.9                   1.4
# 9                    4.9                  3.1                   1.5
# 10                   5.4                  3.7                   1.5
# 11                   4.8                  3.4                   1.6
# 12                   4.8                  3.0                   1.4
# 13                   4.3                  3.0                   1.1
# 14                   5.8                  4.0                   1.2
# 15                   5.7                  4.4                   1.5
# 16                   5.4                  3.9                   1.3
# 17                   5.1                  3.5                   1.4
# 18                   5.7                  3.8                   1.7
# 19                   5.1                  3.8                   1.5
# 20                   5.4                  3.4                   1.7
# 21                   5.1                  3.7                   1.5
# 22                   4.6                  3.6                   1.0
# 23                   5.1                  3.3                   1.7
# 24                   4.8                  3.4                   1.9
# 25                   5.0                  3.0                   1.6
# 26                   5.0                  3.4                   1.6
# 27                   5.2                  3.5                   1.5
# 28                   5.2                  3.4                   1.4
# 29                   4.7                  3.2                   1.6
# 30                   4.8                  3.1                   1.6
# 31                   5.4                  3.4                   1.5
# 32                   5.2                  4.1                   1.5
# 33                   5.5                  4.2                   1.4
# 34                   4.9                  3.1                   1.5
# 35                   5.0                  3.2                   1.2
# 36                   5.5                  3.5                   1.3
# 37                   4.9                  3.1                   1.5
# 38                   4.4                  3.0                   1.3
# 39                   5.1                  3.4                   1.5
# 40                   5.0                  3.5                   1.3
# 41                   4.5                  2.3                   1.3
# 42                   4.4                  3.2                   1.3
# 43                   5.0                  3.5                   1.6
# 44                   5.1                  3.8                   1.9
# 45                   4.8                  3.0                   1.4
# 46                   5.1                  3.8                   1.6
# 47                   4.6                  3.2                   1.4
# 48                   5.3                  3.7                   1.5
# 49                   5.0                  3.3                   1.4
#
#     Petal width (in cm)        Class  SepalExtra
# 0                   0.2  Iris-setosa       17.85
# 1                   0.2  Iris-setosa       14.70
# 2                   0.2  Iris-setosa       15.04
# 3                   0.2  Iris-setosa       14.26
# 4                   0.2  Iris-setosa       18.00
# 5                   0.4  Iris-setosa       21.06
# 6                   0.3  Iris-setosa       15.64
# 7                   0.2  Iris-setosa       17.00
# 8                   0.2  Iris-setosa       12.76
# 9                   0.1  Iris-setosa       15.19
# 10                  0.2  Iris-setosa       19.98
# 11                  0.2  Iris-setosa       16.32
# 12                  0.1  Iris-setosa       14.40
# 13                  0.1  Iris-setosa       12.90
# 14                  0.2  Iris-setosa       23.20
# 15                  0.4  Iris-setosa       25.08
# 16                  0.4  Iris-setosa       21.06
# 17                  0.3  Iris-setosa       17.85
# 18                  0.3  Iris-setosa       21.66
# 19                  0.3  Iris-setosa       19.38
# 20                  0.2  Iris-setosa       18.36
# 21                  0.4  Iris-setosa       18.87
# 22                  0.2  Iris-setosa       16.56
# 23                  0.5  Iris-setosa       16.83
# 24                  0.2  Iris-setosa       16.32
# 25                  0.2  Iris-setosa       15.00
# 26                  0.4  Iris-setosa       17.00
# 27                  0.2  Iris-setosa       18.20
# 28                  0.2  Iris-setosa       17.68
# 29                  0.2  Iris-setosa       15.04
# 30                  0.2  Iris-setosa       14.88
# 31                  0.4  Iris-setosa       18.36
# 32                  0.1  Iris-setosa       21.32
# 33                  0.2  Iris-setosa       23.10
# 34                  0.1  Iris-setosa       15.19
# 35                  0.2  Iris-setosa       16.00
# 36                  0.2  Iris-setosa       19.25
# 37                  0.1  Iris-setosa       15.19
# 38                  0.2  Iris-setosa       13.20
# 39                  0.2  Iris-setosa       17.34
# 40                  0.3  Iris-setosa       17.50
# 41                  0.3  Iris-setosa       10.35
# 42                  0.2  Iris-setosa       14.08
# 43                  0.6  Iris-setosa       17.50
# 44                  0.4  Iris-setosa       19.38
# 45                  0.3  Iris-setosa       14.40
# 46                  0.2  Iris-setosa       19.38
# 47                  0.2  Iris-setosa       14.72
# 48                  0.2  Iris-setosa       19.61
# 49                  0.2  Iris-setosa       16.50

# %% [markdown]
# ### Take only the top 10 rows of the dataset with only first 3 columns and store it in a dataframe named "IrisSubset"

# %%
IrisSubset=iris.iloc[:10,:3]
print("the Iris Subset is" + str(IrisSubset))
# Out:
# the Iris Subset is   Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
# 5                   5.4                  3.9                   1.7
# 6                   4.6                  3.4                   1.4
# 7                   5.0                  3.4                   1.5
# 8                   4.4                  2.9                   1.4
# 9                   4.9                  3.1                   1.5
